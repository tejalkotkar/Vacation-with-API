# %% [markdown]
# # WeatherPy
# ----
# ### Observations:
#
# * Temperature has clear corelation with lattitude.
# * The weather becomes slightly warmer as one approches equator. The sourthern hemisphere tends to be more warmer than northan with max temp lying between 40-100
# * Cloudiness and lattitude does not corelate. However it is interesting to see strong bond of cities near 0, 78 & 100% cloudiness
# * Wind speed tends to generally be betweeen 0 and 15 mph regardless of latitude
# * There is no strong relationship between humidity and lattitude. However, there is slightly large cluster of cities with high humidity in northern hemisphere(above 60% humidity)
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Importing required modules

import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from datetime import date
from scipy.stats import linregress

# Imporing API key
import sys
sys.path.append('..')
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate Cities List

# %%
# Created two empty lists to store lat-langs & cities list
lat_langs = []
cities = []

# Create a set of random lat and lang combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1600)
langs = np.random.uniform(low=-180.000, high=180.000, size=1600)

# Zip lat & lang 
lat_langs = zip(lats, langs)

# Iterate through each lat-lang combination
for lat_lang in lat_langs:
    
    #Get the city name by using citipy module
    city = citipy.nearest_city(lat_lang[0],lat_lang[1]).city_name
    
    # Adding a city to cities list, only if its not already there
    if city not in cities:
        cities.append(city)
        
# Print the number of cities in cities list
len(cities)
# Out:
# 657

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create a dataframe to store values. 
# City column is populated with cities list
city_weather = pd.DataFrame({"City" : cities, "Lat":"", "Lng" : "", "Max Temp" : "", "Humidity" : "",
                             "Cloudiness" : "", "Wind Speed" : "", "Country" : "",  "Date" : ""})

# Display preview of DataFrame
city_weather.head()
# Out:
#            City Lat Lng Max Temp Humidity Cloudiness Wind Speed Country Date
# 0  nizhniy odes
# 1         vaini
# 2   clyde river
# 3       rikitea
# 4      khatanga

# %%
# Define base url with api key added & units declared as imperial to get the temp values in Farenheit
url = "http://api.openweathermap.org/data/2.5/weather?" + "&appid=" + weather_api_key + "&units=imperial"

# Initialised variables to track record set & number
recordset = 1
recordnum = 1

print("Beginning Data Retrieval\n-----------------------------")

# Iterate through each row of DataFrame
for index, row in city_weather.iterrows():
    # Store the city from DataFrame row to variable
    city = row['City']
    
    # Create a query url by appending city to base url
    query_url = url + "&q=" + city
    
    # Send get request to url & store the data in jason format
    response = requests.get(query_url).json()
    
    # Execute try block to store obtained values to DataFrame
    try:
        print(f"Processing Record {recordnum} of Set {recordset} | {response['name']}")
        city_weather.loc[index,'Lat'] = response['coord']['lat']
        city_weather.loc[index,'Lng'] = response['coord']['lon']
        city_weather.loc[index,'Max Temp'] = response['main']['temp_max']
        city_weather.loc[index,'Humidity'] = response['main']['humidity']
        city_weather.loc[index,'Cloudiness'] = response['clouds']['all']
        city_weather.loc[index,'Wind Speed'] = response['wind']['speed']
        city_weather.loc[index,'Country'] = response['sys']['country']
        city_weather.loc[index,'Date'] = response['dt']
        recordnum+=1
    # Execute the except block if city is not obtained from weather API
    except(KeyError, IndexError):
        print("City not found. Skipping...")
    
    # Once the record number completes 50, starts new record set
    if recordnum == 51:
        recordset+=1
        recordnum = 1
print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 |
# Processing Record 5 of Set 5 | Merauke
# Processing Record 6 of Set 5 | Pangnirtung
# City not found. Skipping...
# Processing Record 7 of Set 5 | Motril
# Processing Record 8 of Set 5 | Erzin
# Processing Record 9 of Set 5 | Port Hedland
# Processing Record 10 of Set 5 | Nichinan
# Processing Record 11 of Set 5 | Saint Paul Harbor
# Processing Record 12 of Set 5 | Acarí
# Processing Record 13 of Set 5 | Koungou
# Processing Record 14 of Set 5 | Mweka
# Processing Record 15 of Set 5 | Yangi Marg`ilon
# Processing Record 16 of Set 5 | Bubaque
# Processing Record 17 of Set 5 | Kulhudhuffushi
# Processing Record 18 of Set 5 | Margherita
# Processing Record 19 of Set 5 | Basco
# Processing Record 20 of Set 5 | Oranjemund
# Processing Record 21 of Set 5 | Bandarbeyla
# Processing Record 22 of Set 5 | Balingasay
# Processing Record 23 of Set 5 | Beringovskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | Salinópolis
# Processing Record 25 of Set 5 | Celestún
# Processing Record 26 of Set 5 | Brownsville
# Processing Record 27 of Set 5 | Port Blair
# Processing Record 28 of Set 5 | Guerrero Negro
# Processing Record 29 of Set 5 | Chanika
# Processing Record 30 of Set 5 | Severnoye
# Processing Record 31 of Set 5 | Chuchkovo
# Processing Record 32 of Set 5 | Manta
# Processing Record 33 of Set 5 | Río Cuarto
# Processing Record 34 of Set 5 | Meulaboh
# Processing Record 35 of Set 5 | Quatre Cocos
# Processing Record 36 of Set 5 | Tasiilaq
# Processing Record 37 of Set 5 | Xinpu
# Processing Record 38 of Set 5 | São João da Barra
# Processing Record 39 of Set 5 | Sayyan
# Processing Record 40 of Set 5 | Beyneu
# Processing Record 41 of Set 5 | East London
# Processing Record 42 of Set 5 | Belmonte
# City not found. Skipping...
# Processing Record 43 of Set 5 | Luís Correia
# Processing Record 44 of Set 5 | La Orilla
# Processing Record 45 of Set 5 | Chiredzi
# Processing Record 46 of Set 5 | Tonantins
# Processing Record 47 of Set 5 | Yarmouth
# Processing Record 48 of Set 5 | Marsh Harbour
# Processing Record 49 of Set 5 | Santa Cruz de La Palma
# Processing Record 50 of Set 5 | Labuan
# City not found. Skipping...
# Processing Record 1 of Set 6 | Farah
# Processing Record 2 of Set 6 | Atar
# Processing Record 3 of Set 6 | Pauini
# Processing Record 4 of Set 6 | Naryan-Mar
# Processing Record 5 of Set 6 | Cap Malheureux
# City not found. Skipping...
# Processing Record 6 of Set 6 | Lorengau
# Processing Record 7 of Set 6 | Cabo San Lucas
# Processing Record 8 of Set 6 | Bilibino
# Processing Record 9 of Set 6 | Tosya
# Processing Record 10 of Set 6 | Broome
# Processing Record 11 of Set 6 | Phetchaburi
# Processing Record 12 of Set 6 | Puro
# Processing Record 13 of Set 6 | Lagoa
# Processing Record 14 of Set 6 | Itarantim
# Processing Record 15 of Set 6 | Lata
# Processing Record 16 of Set 6 | Balkanabat
# Processing Record 17 of Set 6 | Bārsi
# Processing Record 18 of Set 6 | Ancud
# Processing Record 19 of Set 6 | Bethel
# Processing Record 20 of Set 6 | Ponta do Sol
# Processing Record 21 of Set 6 | Saskylakh
# Processing Record 22 of Set 6 | Yeppoon
# Processing Record 23 of Set 6 | Padang
# Processing Record 24 of Set 6 | Marinette
# Processing Record 25 of Set 6 | Touros
# Processing Record 26 of Set 6 | Guarapari
# Processing Record 27 of Set 6 | Esperance
# Processing Record 28 of Set 6 | Shelburne
# Processing Record 29 of Set 6 | Deputatsky
# Processing Record 30 of Set 6 | Biak
# Processing Record 31 of Set 6 | Upernavik
# Processing Record 32 of Set 6 | Rena
# Processing Record 33 of Set 6 | Syriam
# Processing Record 34 of Set 6 | Moree
# Processing Record 35 of Set 6 | North Bend
# Processing Record 36 of Set 6 | Vung Tau
# Processing Record 37 of Set 6 | Kismayo
# Processing Record 38 of Set 6 | Anadyr
# Processing Record 39 of Set 6 | Ambovombe
# Processing Record 40 of Set 6 | Auki
# Processing Record 41 of Set 6 | Kenai
# Processing Record 42 of Set 6 | Seydi
# Processing Record 43 of Set 6 | Hvide Sande
# City not found. Skipping...
# Processing Record 44 of Set 6 | Herat Province
# Processing Record 45 of Set 6 | Kem'
# Processing Record 46 of Set 6 | Necochea
# Processing Record 47 of Set 6 | Aklavik
# Processing Record 48 of Set 6 | Geraldton
# City not found. Skipping...
# Processing Record 49 of Set 6 | Laas
# Processing Record 50 of Set 6 | Kalmunai
# City not found. Skipping...
# Processing Record 1 of Set 7 | Pushkinskiye Gory
# Processing Record 2 of Set 7 | Waingapu
# Processing Record 3 of Set 7 | Mergen
# Processing Record 4 of Set 7 | Beloha
# Processing Record 5 of Set 7 | Zirl
# Processing Record 6 of Set 7 | Vostok
# Processing Record 7 of Set 7 | Mahébourg
# Processing Record 8 of Set 7 | Puerto Maldonado
# Processing Record 9 of Set 7 | Villamontes
# Processing Record 10 of Set 7 | Aranjuez
# Processing Record 11 of Set 7 | Abrau-Dyurso
# Processing Record 12 of Set 7 | Praia
# Processing Record 13 of Set 7 | Tevaitoa
# Processing Record 14 of Set 7 | Lüderitz
# Processing Record 15 of Set 7 | Podosinovets
# Processing Record 16 of Set 7 | Talara
# Processing Record 17 of Set 7 | Aasiaat
# Processing Record 18 of Set 7 | Rocha
# Processing Record 19 of Set 7 | Arman'
# Processing Record 20 of Set 7 | Shahreza
# Processing Record 21 of Set 7 | Kupang
# Processing Record 22 of Set 7 | Sola
# Processing Record 23 of Set 7 | Carutapera
# Processing Record 24 of Set 7 | Kruisfontein
# Processing Record 25 of Set 7 | Udachny
# Processing Record 26 of Set 7 | Avera
# City not found. Skipping...
# Processing Record 27 of Set 7 | Río Gallegos
# Processing Record 28 of Set 7 | Sucha Beskidzka
# Processing Record 29 of Set 7 | Gondanglegi
# Processing Record 30 of Set 7 | Metro
# Processing Record 31 of Set 7 | Turukhansk
# Processing Record 32 of Set 7 | Marzuq
# Processing Record 33 of Set 7 | Aykhal
# Processing Record 34 of Set 7 | San Marcos
# Processing Record 35 of Set 7 | Port Hardy
# Processing Record 36 of Set 7 | Peterhead
# Processing Record 37 of Set 7 | Mumford
# Processing Record 38 of Set 7 | Yar-Sale
# Processing Record 22 of Set 10 | Baykit
# Processing Record 23 of Set 10 | Nouna
# Processing Record 24 of Set 10 | Manokwari
# Processing Record 25 of Set 10 | Şereflikoçhisar
# Processing Record 26 of Set 10 | Diamantino
# Processing Record 27 of Set 10 | Pudozh
# City not found. Skipping...
# Processing Record 28 of Set 10 | Bac Lieu
# Processing Record 29 of Set 10 | Mariehamn
# Processing Record 30 of Set 10 | The Valley
# Processing Record 31 of Set 10 | Portland
# Processing Record 32 of Set 10 | Bayan
# Processing Record 33 of Set 10 | Kavaratti
# Processing Record 34 of Set 10 | Hanna
# Processing Record 35 of Set 10 | Gladstone
# Processing Record 36 of Set 10 | Okha
# Processing Record 37 of Set 10 | Honningsvåg
# Processing Record 38 of Set 10 | Dodge City
# Processing Record 39 of Set 10 | Kushmurun
# Processing Record 40 of Set 10 | Saint-François
# City not found. Skipping...
# Processing Record 41 of Set 10 | Ayan
# Processing Record 42 of Set 10 | Makkah al Mukarramah
# Processing Record 43 of Set 10 | Muriti
# Processing Record 44 of Set 10 | Tautira
# Processing Record 45 of Set 10 | Najrān
# Processing Record 46 of Set 10 | Acapulco de Juárez
# Processing Record 47 of Set 10 | Marystown
# Processing Record 48 of Set 10 | Kumul
# Processing Record 49 of Set 10 | Khor
# Processing Record 50 of Set 10 | Sittwe
# Processing Record 1 of Set 11 | Miracema do Tocantins
# Processing Record 2 of Set 11 | Saraland
# Processing Record 3 of Set 11 | Lithgow
# Processing Record 4 of Set 11 | Tuatapere
# City not found. Skipping...
# Processing Record 5 of Set 11 | Bandar
# Processing Record 6 of Set 11 | Halmstad
# Processing Record 7 of Set 11 | Saint-Pierre
# Processing Record 8 of Set 11 | Sete Lagoas
# Processing Record 9 of Set 11 | Calgary
# Processing Record 10 of Set 11 | Manaure
# Processing Record 11 of Set 11 | Palmer
# Processing Record 12 of Set 11 | Narsaq
# City not found. Skipping...
# Processing Record 13 of Set 11 | Quelimane
# Processing Record 14 of Set 11 | Kirensk
# Processing Record 15 of Set 11 | Makakilo City
# Processing Record 16 of Set 11 | Chui
# Processing Record 17 of Set 11 | Berdigestyakh
# Processing Record 18 of Set 11 | Kralendijk
# Processing Record 19 of Set 11 | Hasaki
# Processing Record 20 of Set 11 | Dehlorān
# Processing Record 21 of Set 11 | Mount Gambier
# Processing Record 22 of Set 11 | Alofi
# Processing Record 23 of Set 11 | Road Town
# Processing Record 24 of Set 11 | Callaway
# Processing Record 25 of Set 11 | Bam
# Processing Record 26 of Set 11 | La Palma
# Processing Record 27 of Set 11 | Hobyo
# Processing Record 28 of Set 11 | Forestville
# Processing Record 29 of Set 11 | Izazi
# Processing Record 30 of Set 11 | Kargopol'
# Processing Record 31 of Set 11 | Abnūb
# Processing Record 32 of Set 11 | Ampanihy
# Processing Record 33 of Set 11 | Banjar
# Processing Record 34 of Set 11 | Revelstoke
# Processing Record 35 of Set 11 | Emba
# Processing Record 36 of Set 11 | Piotrków Trybunalski
# Processing Record 37 of Set 11 | Pitsunda
# Processing Record 38 of Set 11 | Zabid
# Processing Record 39 of Set 11 | Tumbagaan
# Processing Record 40 of Set 11 | Muzhi
# Processing Record 41 of Set 11 | Matam
# Processing Record 42 of Set 11 | Port Huron
# Processing Record 43 of Set 11 | Norman Wells
# Processing Record 44 of Set 11 | Oddur
# Processing Record 45 of Set 11 | Sibiti
# Processing Record 46 of Set 11 | Stephenville
# Processing Record 47 of Set 11 | Puerto El Triunfo
# Processing Record 48 of Set 11 | San Cristobal
# Processing Record 49 of Set 11 | Chernushka
# Processing Record 50 of Set 11 | Belyy Yar
# Processing Record 1 of Set 12 | Puerto Madero
# Processing Record 2 of Set 12 | Santo Augusto
# Processing Record 3 of Set 12 | Shirochanskoye
# Processing Record 4 of Set 12 | Verkhniachka
# Processing Record 5 of Set 12 | Sur
# Processing Record 6 of Set 12 | Wiarton
# Processing Record 7 of Set 12 | Shimoda
# Processing Record 8 of Set 12 | São José da Coroa Grande
# Processing Record 9 of Set 12 | Havøysund
# Processing Record 10 of Set 12 | Mishkino
# Processing Record 11 of Set 12 | Tanete
# Processing Record 12 of Set 12 | Omsukchan
# Processing Record 13 of Set 12 | Khanbari
# Processing Record 14 of Set 12 | Chapais
# Processing Record 15 of Set 12 | Viedma
# Processing Record 16 of Set 12 | ‘Āhuimanu
# Processing Record 17 of Set 12 | Srīvardhan
# Processing Record 18 of Set 12 | Sitka
# Processing Record 19 of Set 12 | Oriximiná
# Processing Record 20 of Set 12 | Gergebil'
# Processing Record 21 of Set 12 | Benjamín Aceval
# Processing Record 22 of Set 12 | Oodweyne
# Processing Record 23 of Set 12 | Ballina
# Processing Record 24 of Set 12 | Dubbo
# Processing Record 25 of Set 12 | Baishishan
# Processing Record 26 of Set 12 | Pampa
# Processing Record 27 of Set 12 | Araouane
# Processing Record 28 of Set 12 | Arauca
# Processing Record 29 of Set 12 | Drayton Valley
# Processing Record 30 of Set 12 | Titlāgarh
# Processing Record 31 of Set 12 | Tessalit
# Processing Record 32 of Set 12 | Meridian
# Processing Record 33 of Set 12 | Salym
# Processing Record 34 of Set 12 | Kununurra
# Processing Record 35 of Set 12 | Mayo
# City not found. Skipping...
# Processing Record 36 of Set 12 | De-Kastri
# Processing Record 37 of Set 12 | Shache
# Processing Record 38 of Set 12 | La Santisima Trinidad
# Processing Record 39 of Set 12 | Yaan
# Processing Record 40 of Set 12 | Moroni
# Processing Record 41 of Set 12 | Chegem
# Processing Record 42 of Set 12 | Chara
# Processing Record 43 of Set 12 | Sisimiut
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 12 | Karratha
# Processing Record 45 of Set 12 | Kirando
# Processing Record 46 of Set 12 | Zeya
# Processing Record 47 of Set 12 | Coahuayana Viejo
# Processing Record 48 of Set 12 | Bānswāda
# Processing Record 49 of Set 12 | Samarai
# Processing Record 50 of Set 12 | Ucluelet
# Processing Record 1 of Set 13 | Along
# Processing Record 2 of Set 13 | Haicheng
# Processing Record 3 of Set 13 | Province of Mantua
# Processing Record 4 of Set 13 | San-Pédro
# City not found. Skipping...
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Replace blank values in DataFrame with NaN
city_weather = city_weather.replace("", np.nan, regex=True)

# Checking missing values in DataFrame
city_weather.count()
# Out:
# City          657
# Lat           604
# Lng           604
# Max Temp      604
# Humidity      604
# Cloudiness    604
# Wind Speed    604
# Country       604
# Date          604
# dtype: int64

# %%
# Drop rows with blank(NaN) values
city_weather = city_weather.dropna(how='any')

# Checking if there are any missing values. 
# All column displaying same values iondicate there are no missing values
city_weather.count()
# Out:
# City          604
# Lat           604
# Lng           604
# Max Temp      604
# Humidity      604
# Cloudiness    604
# Wind Speed    604
# Country       604
# Date          604
# dtype: int64

# %%
# Save a clean data to csv
city_weather.to_csv("city_weather_data.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Display statistical summary of DataFrame
city_weather.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  604.000000  604.000000  604.000000  604.000000  604.000000  604.000000
# mean    20.083377   17.596722   58.625430   72.465232   51.230132    8.009404
# std     33.240750   92.231498   23.294709   21.253827   40.868454    5.681043
# min    -54.800000 -179.170000  -14.550000    6.000000    0.000000    0.340000
# 25%     -7.720000  -65.990000   42.447500   62.000000    1.000000    3.880000
# 50%     21.570000   26.185000   63.310000   78.000000   66.000000    6.375000
# 75%     48.182500   99.622500   78.015000   88.000000   90.000000   11.172500
# max     78.220000  179.320000   98.600000  100.000000  100.000000   38.030000
#
#                Date
# count  6.040000e+02
# mean   1.603910e+09
# std    9.926967e+01
# min    1.603910e+09
# 25%    1.603910e+09
# 50%    1.603910e+09
# 75%    1.603910e+09
# max    1.603910e+09

# %% [markdown]
# #### Above table displays max Humidity, which is 100 hence skipping step to remove cities with humidity > 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Store today's date to variable
today = date.today()

# Defined a method to create and display scatter plot.
# Which takes arguments as y-axis values, y-axis label, title of plot & Image name to save the plot

def lat_plot(yaxis, ylabel, title, image_name):
    # Plot scatter plot with Lattitude as x-axis and provided Y-axis values
    plt.scatter(city_weather["Lat"], yaxis, edgecolors="black")
    
    # Set the title, x & y labels, y limits for the plot
    plt.title(title)   
    plt.xlabel("Lattitude")
    plt.ylabel(ylabel)
    plt.ylim(yaxis.min()-10, yaxis.max()+10)
    
    # Display grid with grey color
    plt.grid(color="grey")
    
    # Save the plot with image_name provided in specified path
    plt.savefig(f"Plot_Images/{image_name}")
    
    # Display plot
    plt.show()

# %%
# Store the title for Lattitude Vs Temperature plot to variable
title = "City Latitude vs. Max Temperature ({})".format(today.strftime("%m/%d/%y"))

# Call lat_plot method with below parameters:
# city_weather["Max Temp"] as y axis values
# y label as "Max Temperature (F)"
# title as stored above in title variable
# Image name as "1_Lat_Temp_Scatter.png"

lat_plot(city_weather["Max Temp"], "Max Temperature (F)", title, "1_Lat_Temp_Scatter.png")

# %% [markdown]
# #### It appears that temperature and lattitude are corelated. As moving towards equator, temp appears to be increasing.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Store the title for Lattitude Vs Humidity plot to variable
title = "City Latitude vs. Humidity ({})".format(today.strftime("%m/%d/%y"))

# Call lat_plot method and with parameters:
# city_weather["Humidity"] as y axis values
# "Humidity(%)" as ylabel
# title variable as plot title
# "2_Lat_Humidity_Scatter.png" as Image name

lat_plot(city_weather["Humidity"], "Humidity(%)", title, "2_Lat_Humidity_Scatter.png")

# %% [markdown]
# #### It appears that Lattitude and Humidity are not corelated. There are some data clusters which may indicate that there are more number of cities clusterd in that area

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Store the title for Lattitude Vs cloudiness plot to variable
title = "City Latitude vs. Cloudiness ({})".format(today.strftime("%m/%d/%y"))

# Call lat_plot method and with parameters:
# city_weather["Cloudiness"] as y axis values
# "Cloudiness(%)" as ylabel
# title variable as plot title
# "3_Lat_Cloudiness_Scatter.png" as Image name

lat_plot(city_weather["Cloudiness"], "Cloudiness(%)", title, "3_Lat_Cloudiness_Scatter.png")

# %% [markdown]
# #### Lattitude and cloudiness does not seem to corelate at all. However there are major data clusters at 0,78,90,100

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Store the title for Lattitude Vs Wind Speed plot to variable
title = "City Latitude vs. Wind Speed ({})".format(today.strftime("%m/%d/%y"))

# Call lat_plot method and with parameters:
# city_weather["Wind Speed"] as y axis values
# "Wind Speed(mph)" as ylabel
# title variable as plot title
# "4_Lat_WindSpeed_Scatter.png" as Image name

lat_plot(city_weather["Wind Speed"], "Wind Speed(mph)", title, "4_Lat_WindSpeed_Scatter.png")

# %% [markdown]
# #### Lattitude and wind speed does not seem to corelate at all. However across the lattitude between -40 to 70, major data clusters are between wind speed of 0-10

# %% [markdown]
# ## Linear Regression

# %%
# Store cities with lattitude >= 0 to north_cities df & display count
north_cities = city_weather.loc[city_weather["Lat"] >= 0 , :]
print(north_cities.count())

# Store cities with lattitude < 0 to south_cities df & display count
south_cities = city_weather.loc[city_weather["Lat"] < 0 , :]
print(south_cities.count())
# Out:
# City          407
# Lat           407
# Lng           407
# Max Temp      407
# Humidity      407
# Cloudiness    407
# Wind Speed    407
# Country       407
# Date          407
# dtype: int64
# City          197
# Lat           197
# Lng           197
# Max Temp      197
# Humidity      197
# Cloudiness    197
# Wind Speed    197
# Country       197
# Date          197
# dtype: int64

# %%
# Defined method to calculate linear regression, parameters as below:
# y_values = series/column values to plot on y-axis
# ylabel = string to display as y-label
# image_name = .png file name to save plot as image
# hemisphere = Values as "North" or "South" to get the Lattitude as x-values from respective dataframe
# eqplace = location to place equation on plot

def lat_linear(y_values, ylabel, image_name, hemisphere, eqplace):
    # Get the x-values according to which hemisphere has passed when calling function/methid
    if hemisphere == "North":
        x_values = north_cities["Lat"]
    elif hemisphere == "South":
        x_values = south_cities["Lat"]
    
    # Get the linear equation
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot the scatter plot
    plt.scatter(x_values,y_values, edgecolors="black", facecolors="turquoise")
    plt.plot(x_values,regress_values,"r-")
    
    # Annotate the line_equation on graph
    plt.annotate(line_eq,eqplace,fontsize=15,color="blue",fontweight="bold")
    
    # Set label for x & y axis
    plt.xlabel("Lattitude")
    plt.ylabel(ylabel)
    
    # Print r-value
    print(f"The r-value is: {rvalue}")
    
    # Save plot image
    plt.savefig(f"Plot_Images/{image_name}")
    
    # Display Plot
    plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for temp vs lattitude for Northern Hemisphere
# Parameters as below:
# y_values = north_cities["Max Temp"]
# ylabel = "Max Temp"
# image_name = "5_north_Lat_temp_regression.png"
# hemisphere = "North"
# eqplace = (0,10)

lat_linear(north_cities["Max Temp"], "Max Temp", "5_north_Lat_temp_regression.png", "North", (0,10))
# Out:
# The r-value is: -0.8791477262618272

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for temp vs lattitude for Sourthern Hemisphere
# Parameters as below:
# y_values = south_cities["Max Temp"]
# ylabel = "Max Temp"
# image_name = "6_south_Lat_temp_regression.png"
# hemisphere = "South"
# eqplace = (-55,90)

lat_linear(south_cities["Max Temp"], "Max Temp", "6_south_Lat_temp_regression.png", "South", (-55,90))
# Out:
# The r-value is: 0.6860489114403746

# %% [markdown]
# #### The r value shows strong between temp & lattitude i.e temp increases as we get closer to equator. However, the corelation is not as strong in Sourthern Hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Humidity vs lattitude for Northern Hemisphere
# Parameters as below:
# y_values = north_cities["Humidity"]
# ylabel = "Humidity"
# image_name = "7_north_Lat_humidity_regression.png"
# hemisphere = "North"
# eqplace = (42,20)

lat_linear(north_cities["Humidity"], "Humidity", "7_north_Lat_humidity_regression.png", "North", (42,20))
# Out:
# The r-value is: 0.35252187096036847

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Humidity vs lattitude for Southern Hemisphere
# Parameters as below:
# y_values = south_cities["Humidity"]
# ylabel = "Humidity"
# image_name = "8_south_Lat_humidity_regression.png"
# hemisphere = "South"
# eqplace = (-25,12)

lat_linear(south_cities["Humidity"], "Humidity", "8_south_Lat_humidity_regression.png", "South", (-25,12))
# Out:
# The r-value is: 0.0756647948837791

# %% [markdown]
# #### There is no strong corelation between Humidity & latitude. In northern hemisphere it's weekly corelated , indicating it gets drier as we approach equator but not as strong to prove it. In sourthern hemispehere Humidity & latitude does not seem to be corelated at all.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Cloudiness vs lattitude for Northern Hemisphere
# Parameters as below:
# y_values = north_cities["Cloudiness"]
# ylabel = "Cloudiness"
# image_name = "9_north_Lat_cloudiness_regression.png"
# hemisphere = "North"
# eqplace = (35,30)

lat_linear(north_cities["Cloudiness"], "Cloudiness", "9_north_Lat_cloudiness_regression.png", "North", (35,30))
# Out:
# The r-value is: 0.15790622274768779

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Cloudiness vs lattitude for Southern Hemisphere
# Parameters as below:
# y_values = south_cities["Cloudiness"]
# ylabel = "Cloudiness"
# image_name = "10_south_Lat_cloudiness_regression.png"
# hemisphere = "South"
# eqplace = (-55,60)

lat_linear(south_cities["Cloudiness"], "Cloudiness", "10_south_Lat_cloudiness_regression.png", "South", (-55,60))
# Out:
# The r-value is: 0.04947293007228338

# %% [markdown]
# #### Cloudiness & latitude does not seem to have any corelation based off r value for both hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Wind Speed vs lattitude for Northern Hemisphere
# Parameters as below:
# y_values = north_cities["Wind Speed"]
# ylabel = "Wind Speed"
# image_name = "11_north_Lat_WindSpeed_regression.png"
# hemisphere = "North"
# eqplace = (5,30)

lat_linear(north_cities["Wind Speed"], "Wind Speed", "11_north_Lat_WindSpeed_regression.png", "North", (5,30))
# Out:
# The r-value is: 0.13217919504949044

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call lat_linear method defined above to calculate regression for Wind Speed vs lattitude for Southern Hemisphere
# Parameters as below:
# y_values = south_cities["Wind Speed"]
# ylabel = "Wind Speed"
# image_name = "12_south_Lat_WindSpeed_regression.png"
# hemisphere = "South"
# eqplace = (-40,30)

lat_linear(south_cities["Wind Speed"], "Wind Speed", "12_south_Lat_WindSpeed_regression.png", "South", (-40,30))
# Out:
# The r-value is: -0.19464129352478912

# %% [markdown]
# #### Wind Speed & latitude does not seem to have any corelation based off r value for both hemisphere.
